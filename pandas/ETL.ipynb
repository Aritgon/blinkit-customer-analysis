# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
cust_feedback = pd.read_csv(r"C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_customer_feedback_cleaned.csv")
cust_feedback.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   feedback_id        5000 non-null   int64
#  1   order_id           5000 non-null   int64
#  2   customer_id        5000 non-null   int64
#  3   rating             5000 non-null   int64
#  4   feedback_text      5000 non-null   object
#  5   feedback_category  5000 non-null   object
#  6   sentiment          5000 non-null   object
#  7   feedback_date      5000 non-null   object
#  8   feedback_year      5000 non-null   int64
#  9   feedback_month     5000 non-null   int64
#  10  feedback_day_name  5000 non-null   object
#  11  feedback_week      5000 non-null   int64
#  12  feedback_period    5000 non-null   object
#  13  feedback_day       5000 non-null   int64
# dtypes: int64(8), object(6)
# memory usage: 547.0+ KB

# %%
cust_details = pd.read_csv(r"C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_customers_cleaned.csv")
cust_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         2500 non-null   int64
#  1   customer_name       2500 non-null   object
#  2   email               2500 non-null   object
#  3   phone               2500 non-null   int64
#  4   address             2500 non-null   object
#  5   area                2500 non-null   object
#  6   pincode             2500 non-null   int64
#  7   registration_date   2500 non-null   object
#  8   customer_segment    2500 non-null   object
#  9   total_orders        2500 non-null   int64
#  10  avg_order_value     2500 non-null   float64
#  11  registration_year   2500 non-null   int64
#  12  registration_month  2500 non-null   int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 254.0+ KB

# %%
order_details = pd.read_csv(r"C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_orders_cleaned_final.csv")
order_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   order_id                          5000 non-null   int64
#  1   customer_id                       5000 non-null   int64
#  2   order_date                        5000 non-null   object
#  3   promised_delivery_time            5000 non-null   object
#  4   actual_delivery_time              5000 non-null   object
#  5   order_total                       5000 non-null   float64
#  6   payment_method                    5000 non-null   object
#  7   delivery_partner_id               5000 non-null   int64
#  8   store_id                          5000 non-null   int64
#  9   delivery_gap_in_minutes           5000 non-null   float64
#  10  gap_between_promised_actual_time  5000 non-null   float64
# ...

# %% [markdown]
# ### Data injection using pandas and SQLalchemy.

# %%
# Define database credentials
# format : postgresql://username:password@localhost:5432/database_name
DB_URL = "postgresql+psycopg2://postgres:1111@localhost:5432/blinkit_customer_analysis_db"

# connection engine.
conn = create_engine(DB_URL)

# file to upload.
files = {
    # 'Data/cleaned/blinkit_orders_cleaned_final.csv' : 'blinkit_orders', # this was injected into the main table in postgres.
    'Data/cleaned/blinkit_customers_cleaned.csv' : 'blinkit_customer_details',
    'Data/cleaned/blinkit_customer_feedback_cleaned.csv' : 'blinkit_customer_feedback',
}

for file_name, table_name in files.items():
    print(f"Uploading {file_name} to table {table_name}...")

    # reading each file with each iteration.
    df=pd.read_csv(file_name)

    # Uploading to postgreSQL database.
    df.to_sql(table_name, conn, if_exists="append", index=False)

    print(f"file {file_name} is successfully uploaded to {table_name}.")

print("All datasets uploaded successfully!")

# %% [markdown]
# Injecting the data of blinkit_order_items and blinkit_products into the blinkit_customer_analysis_db for further project related analysis.

# %%
import pandas as pd
from sqlalchemy import create_engine

# define database credentials.
# format : sql_dialect+driver//owner_name:owner_password@servername:serverport/database_name
DB_URL = "postgresql+psycopg2://postgres:1111@localhost:5432/blinkit_customer_analysis_db"

conn = create_engine(DB_URL)

# file structure in dictionary form.
files = {
    # file name : table name
    r'C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_product_cleaned.csv' : 'blinkit_products', # file_name
    r'C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_order_items_cleaned.csv' : 'blinkit_order_items' # table_name
}

for file_name, table_name in files.items():
    print(f"reading {file_name} to inject in {table_name}...")

    # read the file with each iteration.
    df = pd.read_csv(file_name)

    # inject the data to the destined database URL.
    df.to_sql(table_name, conn, if_exists="append", index=False)

    print(f"file : {file_name} injection is completed in table : {table_name}")

print(f"All files are injected to the database. check your database right now.")
# Out:
# reading C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_product_cleaned.csv to inject in blinkit_products...
# file : C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_product_cleaned.csv injection is completed in table : blinkit_products
# reading C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_order_items_cleaned.csv to inject in blinkit_order_items...
# file : C:\Users\Soham Gon\Desktop\blinkit analysis\Data\cleaned\blinkit_order_items_cleaned.csv injection is completed in table : blinkit_order_items
# All files are injected to the database. check your database right now.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 30
#      26     print(f"file : {file_name} injection is completed in table : {table_name}")
#      28 print(f"All files are injected to the database. check your database right now.")
# ...

# %% [markdown]
# ## inject blinkit_Delivery_performace data into the blinkit_customer_analysis_db database.

# %%
import pandas as pd
from sqlalchemy import create_engine

# define database credentials and access path.
DB_URL = "postgresql+psycopg2://postgres:1111@localhost:5432/blinkit_customer_analysis_db"

# creating a dictionary with the file.
files = {
    r''
}
